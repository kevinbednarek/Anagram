# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinbednarek/Anagram/blob/master/Dolly2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install accelerate>=0.12.0 transformers[torch]==4.25.1
import torch

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# Tesla T4

# %%
from transformers import pipeline

generate_text = pipeline(model="databricks/dolly-v2-3b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto")

# %%
generate_text("Write a poem about two ugly dogs that smell bad.")
# Out:
# "Smelly ugly dogs,\nYou stink so bad,\nYou make me want to throw up just thinking of you,\nYou're ugly,\nYou're scabby,\nYou're slobbering,\nYou're covered in hair,\nYour breath is awful,\nYou both drool and pant,\nThey smell even worse than I do,\nYou're hideous,\nYou're hideous,\nYou're hideous,"
